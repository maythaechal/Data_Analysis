# %%
import numpy as np
import pandas as pd

df = pd.read_csv("food_coded.xls")

# %%
df.drop(111, axis=0, inplace=True)

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull().sum()
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             2
# comfort_food_reasons_coded      18
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         16
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                2
# fav_cuisine                      1
# fav_cuisine_coded                0
# ...

# %%
df['GPA'].unique()
# Out:
# array(['2.4', '3.654', '3.3', '3.2', '3.5', '2.25', '3.8', '3.904', '3.4',
#        '3.6', '3.1', nan, '4', '2.2', '3.87', '3.7', '3.9', '2.8', '3',
#        '3.65', '3.89', '2.9', '3.605', '3.83', '3.292', '3.35',
#        'Personal ', '2.6', '3.67', '3.73', '3.79 bitch', '2.71', '3.68',
#        '3.75', '3.92', 'Unknown', '3.77', '3.63', '3.882'], dtype=object)

# %%
# Convert to numeric 
df['GPA'] = pd.to_numeric(df['GPA'], errors='coerce')

# %%
df.dtypes
# Out:
# GPA                             float64
# Gender                            int64
# breakfast                         int64
# calories_chicken                  int64
# calories_day                    float64
# calories_scone                  float64
# coffee                            int64
# comfort_food                     object
# comfort_food_reasons             object
# comfort_food_reasons_coded      float64
# cook                            float64
# comfort_food_reasons_coded.1      int64
# cuisine                         float64
# diet_current                     object
# diet_current_coded                int64
# drink                           float64
# eating_changes                   object
# eating_changes_coded              int64
# eating_changes_coded1             int64
# eating_out                        int64
# employment                      float64
# ethnic_food                       int64
# exercise                        float64
# ...

# %%
# Find row where 'product' == 'apple' and change its 'price' column
row_index = df.loc[df['GPA'] == '3.79 bitch'].index   # first match
df.loc[row_index, 'price'] = 3.79

# %%
df['GPA'].unique()
# Out:
# array([2.4  , 3.654, 3.3  , 3.2  , 3.5  , 2.25 , 3.8  , 3.904, 3.4  ,
#        3.6  , 3.1  ,   nan, 4.   , 2.2  , 3.87 , 3.7  , 3.9  , 2.8  ,
#        3.   , 3.65 , 3.89 , 2.9  , 3.605, 3.83 , 3.292, 3.35 , 2.6  ,
#        3.67 , 3.73 , 2.71 , 3.68 , 3.75 , 3.92 , 3.77 , 3.63 , 3.882])

# %%
mean_GPA = df['GPA'].mean() 
df['GPA'] =  df['GPA'].fillna(mean_GPA)

# %%
df['GPA'].unique()
# Out:
# array([2.4       , 3.654     , 3.3       , 3.2       , 3.5       ,
#        2.25      , 3.8       , 3.904     , 3.4       , 3.6       ,
#        3.1       , 3.41989076, 4.        , 2.2       , 3.87      ,
#        3.7       , 3.9       , 2.8       , 3.        , 3.65      ,
#        3.89      , 2.9       , 3.605     , 3.83      , 3.292     ,
#        3.35      , 2.6       , 3.67      , 3.73      , 2.71      ,
#        3.68      , 3.75      , 3.92      , 3.77      , 3.63      ,
#        3.882     ])

# %%
df['calories_day'].unique()
# Out:
# array([nan,  3.,  4.,  2.])

# %%
mean_cal = df['calories_day'].mean() 
df['calories_day'] =  df['calories_day'].fillna(mean_cal)

# %%
df['calories_day'].unique()
# Out:
# array([3.03809524, 3.        , 4.        , 2.        ])

# %%
df.isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    1
# coffee                            0
# comfort_food                      1
# comfort_food_reasons              2
# comfort_food_reasons_coded       18
# cook                              3
# comfort_food_reasons_coded.1      0
# cuisine                          16
# diet_current                      1
# diet_current_coded                0
# drink                             2
# eating_changes                    3
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        9
# ethnic_food                       0
# exercise                         13
# father_education                  1
# father_profession                 2
# fav_cuisine                       1
# ...

# %%
df.shape
# Out:
# (124, 62)

# %%
df['calories_scone'].unique()
# Out:
# array([315., 420., 980.,  nan])

# %%
mean_cal = df['calories_scone'].mean() 
df['calories_scone'] =  df['calories_scone'].fillna(mean_cal)

# %%
df['calories_scone'].unique()
# Out:
# array([315.        , 420.        , 980.        , 501.38211382])

# %%
df['coffee'].unique()
# Out:
# array([1, 2])

# %%
df['comfort_food'].value_counts()
# Out:
# comfort_food
# none                                                                                                 1
# Mac and cheese, lasagna, Chinese food                                                                1
# Macaroni and cheese, chicken noodle soup, pizza                                                      1
# chips, ice cream, fruit snacks                                                                       1
# carrots, plantain chips, almonds, popcorn                                                            1
# Little Debbie snacks, donuts, pizza                                                                  1
# pizza, pasta, mac and cheese                                                                         1
# Chinese food, moes, sponge candy, homemade lasagne                                                   1
# Ice cream, pizza, cookies                                                                            1
# ...

# %%
mean_cal = df['comfort_food'].mode() 
df['comfort_food'] =  df['comfort_food'].fillna(mean_cal)

# %%
df.dtypes
# Out:
# GPA                             float64
# Gender                            int64
# breakfast                         int64
# calories_chicken                  int64
# calories_day                    float64
# calories_scone                  float64
# coffee                            int64
# comfort_food                     object
# comfort_food_reasons             object
# comfort_food_reasons_coded      float64
# cook                            float64
# comfort_food_reasons_coded.1      int64
# cuisine                         float64
# diet_current                     object
# diet_current_coded                int64
# drink                           float64
# eating_changes                   object
# eating_changes_coded              int64
# eating_changes_coded1             int64
# eating_out                        int64
# employment                      float64
# ethnic_food                       int64
# exercise                        float64
# ...

# %%
df.isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    0
# coffee                            0
# comfort_food                      0
# comfort_food_reasons              2
# comfort_food_reasons_coded       18
# cook                              3
# comfort_food_reasons_coded.1      0
# cuisine                          16
# diet_current                      1
# diet_current_coded                0
# drink                             2
# eating_changes                    3
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        9
# ethnic_food                       0
# exercise                         13
# father_education                  1
# father_profession                 2
# fav_cuisine                       1
# ...

# %%
df['comfort_food_reasons'].unique()
# Out:
# array(['we dont have comfort ', 'Stress, bored, anger', 'stress, sadness',
#        'Boredom', 'Stress, boredom, cravings ',
#        "None, i don't eat comfort food. I just eat when i'm hungry.",
#        'stress, boredom',
#        'I eat comfort food when im stressed out from school(finals week), when I`m sad, or when i am dealing with personal family issues.',
#        'Boredom ', 'Stress, anger and sadness ',
#        'sadness, stress, cold weather',
#        'Sadness, boredom, late night snack ',
#        'stress,  boredom, special occasions',
#        'Friends, environment and boredom', 'boredom', 'Stress ',
#        "I usually only eat comfort food when I'm bored, if i am doing something, i can go for hours without eating ",
#        'Sadness, stress', 'boredom, sadness, hungry',
#        'happiness, satisfaction', 'Mostly boredom',
#        'sadness, depression ', 'Stress and boredom ',
#        'A long day, not feeling well, winter ', 'Boredom, lazyniss ',
# ...

# %%
df['cuisine'].unique()
# Out:
# array([nan,  1.,  3.,  2.,  6.,  4.,  5.])

# %%
mean_cu = df['cuisine'].mean() 
df['cuisine'] =  df['cuisine'].fillna(mean_cu)

# %%
df['cuisine'].unique()
# Out:
# array([1.38888889, 1.        , 3.        , 2.        , 6.        ,
#        4.        , 5.        ])

# %%
df['exercise'].unique()
# Out:
# array([ 1.,  2.,  3., nan])

# %%
df[df['exercise']==' '].index.tolist()
# Out:
# []

# %%
df.isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    0
# coffee                            0
# comfort_food                      0
# comfort_food_reasons              2
# comfort_food_reasons_coded       18
# cook                              3
# comfort_food_reasons_coded.1      0
# cuisine                           0
# diet_current                      1
# diet_current_coded                0
# drink                             2
# eating_changes                    3
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        9
# ethnic_food                       0
# exercise                         13
# father_education                  1
# father_profession                 2
# fav_cuisine                       1
# ...

# %%
numeric_columns =  df.select_dtypes(include=['number']).columns

# %%
df[numeric_columns].isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    0
# coffee                            0
# comfort_food_reasons_coded       18
# cook                              3
# comfort_food_reasons_coded.1      0
# cuisine                           0
# diet_current_coded                0
# drink                             2
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        9
# ethnic_food                       0
# exercise                         13
# father_education                  1
# fav_cuisine_coded                 0
# fav_food                          2
# fries                             0
# fruit_day                         0
# grade_level                       0
# greek_food                        0
# ...

# %%
for column in numeric_columns:
 df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

# %%
ob_columns = df.select_dtypes(include=['object']).columns

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food             0
# comfort_food_reasons     2
# diet_current             1
# eating_changes           3
# father_profession        2
# fav_cuisine              1
# food_childhood           1
# healthy_meal             1
# ideal_diet               1
# meals_dinner_friend      2
# mother_profession        1
# type_sports             25
# weight                   2
# dtype: int64

# %%
for column in numeric_columns:
 df[ob_columns] = df[ob_columns].fillna(df[ob_columns].mode())

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food             0
# comfort_food_reasons     2
# diet_current             0
# eating_changes           3
# father_profession        2
# fav_cuisine              1
# food_childhood           1
# healthy_meal             0
# ideal_diet               0
# meals_dinner_friend      2
# mother_profession        1
# type_sports             25
# weight                   2
# dtype: int64

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0  2.400       2          1               430      3.038095           315.0
# 1  3.654       1          1               610      3.000000           420.0
# 2  3.300       1          1               720      4.000000           420.0
# 3  3.200       1          1               430      3.000000           420.0
# 4  3.500       1          1               720      2.000000           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  sports  thai_food  tortilla_calories  \
# ...

# %%
df['comfort_food_reasons'].unique()
# Out:
# array(['we dont have comfort ', 'Stress, bored, anger', 'stress, sadness',
#        'Boredom', 'Stress, boredom, cravings ',
#        "None, i don't eat comfort food. I just eat when i'm hungry.",
#        'stress, boredom',
#        'I eat comfort food when im stressed out from school(finals week), when I`m sad, or when i am dealing with personal family issues.',
#        'Boredom ', 'Stress, anger and sadness ',
#        'sadness, stress, cold weather',
#        'Sadness, boredom, late night snack ',
#        'stress,  boredom, special occasions',
#        'Friends, environment and boredom', 'boredom', 'Stress ',
#        "I usually only eat comfort food when I'm bored, if i am doing something, i can go for hours without eating ",
#        'Sadness, stress', 'boredom, sadness, hungry',
#        'happiness, satisfaction', 'Mostly boredom',
#        'sadness, depression ', 'Stress and boredom ',
#        'A long day, not feeling well, winter ', 'Boredom, lazyniss ',
# ...

# %%
df['exercise'].unique()
# Out:
# array([1.        , 2.        , 3.        , 1.58558559])

# %%
mean_ex = df['exercise'].mode() 
df['exercise'] =  df['exercise'].fillna(mean_ex)

# %%
df['exercise'].unique()
# Out:
# array([1.        , 2.        , 3.        , 1.58558559])

# %%
df['cook'].unique()
# Out:
# array([2.        , 3.        , 1.        , 5.        , 4.        ,
#        2.79338843])

# %%
mean_cook = df['cook'].mean() 
df['cook'] =  df['cook'].fillna(mean_cook)

# %%
df['cook'].unique()
# Out:
# array([2.        , 3.        , 1.        , 5.        , 4.        ,
#        2.79338843])

# %%
df['comfort_food_reasons_coded'].unique()
# Out:
# array([9.        , 1.        , 2.        , 4.        , 3.        ,
#        7.        , 6.        , 5.        , 8.        , 2.69811321])

# %%
mean_reason = df['comfort_food_reasons_coded'].mean() 
df['comfort_food_reasons_coded'] =  df['comfort_food_reasons_coded'].fillna(mean_reason)

# %%
df['comfort_food_reasons_coded'].unique()
# Out:
# array([9.        , 1.        , 2.        , 4.        , 3.        ,
#        7.        , 6.        , 5.        , 8.        , 2.69811321])

# %%
df['father_education'].unique()
# Out:
# array([5.        , 2.        , 4.        , 1.        , 3.        ,
#        3.49593496])

# %%
mean_fe = df['father_education'].mean() 
df['father_education'] =  df['father_education'].fillna(mean_fe)

# %%
df['father_education'].unique()
# Out:
# array([5.        , 2.        , 4.        , 1.        , 3.        ,
#        3.49593496])

# %%
df.isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    0
# coffee                            0
# comfort_food                      0
# comfort_food_reasons              2
# comfort_food_reasons_coded        0
# cook                              0
# comfort_food_reasons_coded.1      0
# cuisine                           0
# diet_current                      0
# diet_current_coded                0
# drink                             0
# eating_changes                    3
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        0
# ethnic_food                       0
# exercise                          0
# father_education                  0
# father_profession                 2
# fav_cuisine                       1
# ...

# %%
df['drink'].unique()
# Out:
# array([1.        , 2.        , 1.55737705])

# %%
mean_fe = df['drink'].mean() 
df['drink'] =  df['drink'].fillna(mean_fe)

# %%
df['drink'].unique()
# Out:
# array([1.        , 2.        , 1.55737705])

# %%
df['diet_current'].unique()
# Out:
# array(['eat good and exercise',
#        "I eat about three times a day with some snacks. I try to eat healthy but it doesn't always work out that- sometimes eat fast food and mainly eat at Laker/ Egan ",
#        'toast and fruit for breakfast, salad for lunch, usually grilled chicken and veggies (or some variation) for dinner',
#        'College diet, cheap and easy foods most nights. Weekends traditionally, cook better homemade meals  ',
#        'I try to eat healthy but often struggle because of living on campus. I still try to keep the choices I do make balanced with fruits and vegetables and limit the sweats. ',
#        "My current diet is terrible. I barely have time to eat a meal in a day. When i do eat it's mostly not healthy.",
#        'I eat a lot of chicken and broccoli for dinner, and usually tuna sandwiches for lunch.',
#        'I eat a very healthy diet. Ocassionally, i will eat out and get unhealthy food.',
#        'I eat whatever I want in moderation.',
# ...

# %%
mean_dc = df['diet_current'].mode() 
df['diet_current'] =  df['diet_current'].fillna(mean_dc)

# %%
df['diet_current'].unique()
# Out:
# array(['eat good and exercise',
#        "I eat about three times a day with some snacks. I try to eat healthy but it doesn't always work out that- sometimes eat fast food and mainly eat at Laker/ Egan ",
#        'toast and fruit for breakfast, salad for lunch, usually grilled chicken and veggies (or some variation) for dinner',
#        'College diet, cheap and easy foods most nights. Weekends traditionally, cook better homemade meals  ',
#        'I try to eat healthy but often struggle because of living on campus. I still try to keep the choices I do make balanced with fruits and vegetables and limit the sweats. ',
#        "My current diet is terrible. I barely have time to eat a meal in a day. When i do eat it's mostly not healthy.",
#        'I eat a lot of chicken and broccoli for dinner, and usually tuna sandwiches for lunch.',
#        'I eat a very healthy diet. Ocassionally, i will eat out and get unhealthy food.',
#        'I eat whatever I want in moderation.',
# ...

# %%
df.isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    0
# coffee                            0
# comfort_food                      0
# comfort_food_reasons              2
# comfort_food_reasons_coded        0
# cook                              0
# comfort_food_reasons_coded.1      0
# cuisine                           0
# diet_current                      0
# diet_current_coded                0
# drink                             0
# eating_changes                    3
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        0
# ethnic_food                       0
# exercise                          0
# father_education                  0
# father_profession                 2
# fav_cuisine                       1
# ...

# %%
df['comfort_food_reasons'].unique()
# Out:
# array(['we dont have comfort ', 'Stress, bored, anger', 'stress, sadness',
#        'Boredom', 'Stress, boredom, cravings ',
#        "None, i don't eat comfort food. I just eat when i'm hungry.",
#        'stress, boredom',
#        'I eat comfort food when im stressed out from school(finals week), when I`m sad, or when i am dealing with personal family issues.',
#        'Boredom ', 'Stress, anger and sadness ',
#        'sadness, stress, cold weather',
#        'Sadness, boredom, late night snack ',
#        'stress,  boredom, special occasions',
#        'Friends, environment and boredom', 'boredom', 'Stress ',
#        "I usually only eat comfort food when I'm bored, if i am doing something, i can go for hours without eating ",
#        'Sadness, stress', 'boredom, sadness, hungry',
#        'happiness, satisfaction', 'Mostly boredom',
#        'sadness, depression ', 'Stress and boredom ',
#        'A long day, not feeling well, winter ', 'Boredom, lazyniss ',
# ...

# %%
mean_smfe = df['comfort_food_reasons'].mode() 
df['comfort_food_reasons'] =  df['comfort_food_reasons'].fillna(mean_smfe)

# %%
df['eating_changes'].unique()
# Out:
# array(['eat faster ', 'I eat out more than usual. ',
#        'sometimes choosing to eat fast food instead of cooking simply for convenience',
#        'Accepting cheap and premade/store bought foods',
#        'I have eaten generally the same foods but I do find myself eating the same food frequently due to what I have found I like from egan and the laker. ',
#        'Eating rice everyday. Eating less homemade food.',
#        "I started eating a lot less and healthier because I wasn't playing sports year round anymore.",
#        'Freshmen year i ate very unhealthy, but now it is much healthier because of self control.',
#        'I snack less',
#        "I cook a lot of my own foods back at home so not being able to cook my own healthy choices. I eat more carbs than normal when I'm at college due to the choices given in the cafe. ",
#        'Nun ', 'Less meat. ',
#        'I have been eating a lot more salads and soups.',
# ...

# %%
mean_smfe = df['eating_changes'].mode() 
df['eating_changes'] =  df['eating_changes'].fillna(mean_smfe)

# %%
df['eating_changes'].unique()
# Out:
# array(['eat faster ', 'I eat out more than usual. ',
#        'sometimes choosing to eat fast food instead of cooking simply for convenience',
#        'Accepting cheap and premade/store bought foods',
#        'I have eaten generally the same foods but I do find myself eating the same food frequently due to what I have found I like from egan and the laker. ',
#        'Eating rice everyday. Eating less homemade food.',
#        "I started eating a lot less and healthier because I wasn't playing sports year round anymore.",
#        'Freshmen year i ate very unhealthy, but now it is much healthier because of self control.',
#        'I snack less',
#        "I cook a lot of my own foods back at home so not being able to cook my own healthy choices. I eat more carbs than normal when I'm at college due to the choices given in the cafe. ",
#        'Nun ', 'Less meat. ',
#        'I have been eating a lot more salads and soups.',
# ...

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food             0
# comfort_food_reasons     2
# diet_current             0
# eating_changes           3
# father_profession        2
# fav_cuisine              1
# food_childhood           1
# healthy_meal             0
# ideal_diet               0
# meals_dinner_friend      2
# mother_profession        1
# type_sports             25
# weight                   2
# dtype: int64

# %%
df['comfort_food_reasons'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
mode_value = df["comfort_food_reasons"].mode()[0]

df.loc[[74, 88], "comfort_food_reasons"] = mode_value

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food             0
# comfort_food_reasons     0
# diet_current             0
# eating_changes           3
# father_profession        2
# fav_cuisine              1
# food_childhood           1
# healthy_meal             0
# ideal_diet               0
# meals_dinner_friend      2
# mother_profession        1
# type_sports             25
# weight                   2
# dtype: int64

# %%
df['eating_changes'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53      True
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63      True
# 64     False
# 65     False
# ...

# %%
mode_value = df["eating_changes"].mode()[0]

df.loc[[74, 53, 63], "eating_changes"] = mode_value

# %%
df['father_profession'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30      True
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df['fav_cuisine'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['food_childhood'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df['meals_dinner_friend'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
mode_value = df["meals_dinner_friend"].mode()[0]

df.loc[[101], "meals_dinner_friend"] = mode_value

# %%
df['mother_profession'].isnull().sum()
# Out:
# np.int64(1)

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food             0
# comfort_food_reasons     0
# diet_current             0
# eating_changes           0
# father_profession        2
# fav_cuisine              1
# food_childhood           0
# healthy_meal             0
# ideal_diet               0
# meals_dinner_friend      1
# mother_profession        1
# type_sports             25
# weight                   2
# dtype: int64

# %%
df['type_sports'].isnull()

# %%
mode_typ_sp= df['type_sports'].mode() 
df['type_sports'] =  df['type_sports'].fillna(mode_typ_sp)

# %%
null_locs = df[df['type_sports'].isnull()].index
print(null_locs)
# Out:
# Index([  3,  16,  28,  29,  33,  41,  42,  50,  53,  61,  65,  69,  72,  74,
#         80,  88,  93, 101, 102, 106, 112, 113, 118, 123, 124],
#       dtype='int64')

# %%
mode_value = df["type_sports"].mode()[0]

df.loc[[  3,  16,  28,  29,  33,  41,  42,  50,  53,  61,  65,  69,  72,  80,
        88,  93, 101, 102, 106, 112, 113, 118, 123, 124], "type_sports"] = mode_value

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food            0
# comfort_food_reasons    0
# diet_current            0
# eating_changes          0
# father_profession       2
# fav_cuisine             1
# food_childhood          0
# healthy_meal            0
# ideal_diet              0
# meals_dinner_friend     1
# mother_profession       1
# type_sports             1
# weight                  2
# dtype: int64

# %%
df['meals_dinner_friend'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
mode_value = df["meals_dinner_friend"].mode()[0]

df.loc[[102], "meals_dinner_friend"] = mode_value

# %%
df['weight'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32      True
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
mode_value = df["weight"].mode()[0]

df.loc[[32], "weight"] = mode_value

# %%
df[ob_columns].isnull().sum()
# Out:
# comfort_food            0
# comfort_food_reasons    0
# diet_current            0
# eating_changes          0
# father_profession       2
# fav_cuisine             1
# food_childhood          0
# healthy_meal            0
# ideal_diet              0
# meals_dinner_friend     0
# mother_profession       1
# type_sports             1
# weight                  1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# GPA                               0
# Gender                            0
# breakfast                         0
# calories_chicken                  0
# calories_day                      0
# calories_scone                    0
# coffee                            0
# comfort_food                      0
# comfort_food_reasons              0
# comfort_food_reasons_coded        0
# cook                              0
# comfort_food_reasons_coded.1      0
# cuisine                           0
# diet_current                      0
# diet_current_coded                0
# drink                             0
# eating_changes                    0
# eating_changes_coded              0
# eating_changes_coded1             0
# eating_out                        0
# employment                        0
# ethnic_food                       0
# exercise                          0
# father_education                  0
# father_profession                 2
# fav_cuisine                       1
# ...

# %%
df.head(25)
# Out:
#          GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0   2.400000       2          1               430      3.038095
# 1   3.654000       1          1               610      3.000000
# 2   3.300000       1          1               720      4.000000
# 3   3.200000       1          1               430      3.000000
# 4   3.500000       1          1               720      2.000000
# 5   2.250000       1          1               610      3.000000
# 6   3.800000       2          1               610      3.000000
# 7   3.300000       1          1               720      3.000000
# 8   3.300000       1          1               430      3.038095
# 9   3.300000       1          1               430      3.000000
# 10  3.500000       1          1               610      3.000000
# 11  3.904000       1          1               720      4.000000
# 12  3.400000       2          1               430      3.000000
# 13  3.600000       1          1               610      3.000000
# ...

# %%
df['Gender'] = df['Gender'].replace({2: 'female', 1: 'male'})

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0  2.400  female          1               430      3.038095           315.0
# 1  3.654    male          1               610      3.000000           420.0
# 2  3.300    male          1               720      4.000000           420.0
# 3  3.200    male          1               430      3.000000           420.0
# 4  3.500    male          1               720      2.000000           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  sports  thai_food  tortilla_calories  \
# ...

# %%
df['sports'] = df['sports'].replace({'Yes': 'Active', 'No': 'Not-Active'})

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0  2.400  female          1               430      3.038095           315.0
# 1  3.654    male          1               610      3.000000           420.0
# 2  3.300    male          1               720      4.000000           420.0
# 3  3.200    male          1               430      3.000000           420.0
# 4  3.500    male          1               720      2.000000           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %% [markdown]
# ### Using replace(): the numerical data type column

# %%
df['breakfast'] = df['breakfast'].astype(str).replace({'1' : 'Yes', '2' : 'No'})

# %%
df['coffee'] = df['coffee'].astype(str).replace({'1' : 'Yes', '2' : 'No'})

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26284\2848154313.py in ?()
# ----> 1 df.col(none)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'col'
