# %%
import pandas as pd
import numpy as np

df = pd.read_csv("D:\YIU\YIU\LevelFive\BPS\laptopData.xls")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %% [markdown]
# ### Missing Values Handle

# %%
df.isnull().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %% [markdown]
# ## Drop all Absent rows

# %%
df = df.dropna(how='all')

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ## Drop Duplicat Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(29)

# %%
df = df.drop_duplicates(keep= 'first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Find Missing values(?, '', unknown)

# %%
df['Company'].value_counts()
# Out:
# Company
# Lenovo       282
# Dell         281
# HP           260
# Asus         149
# Acer         101
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Fujitsu        2
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              689
# Gaming                203
# Ultrabook             189
# 2 in 1 Convertible    112
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    621
# 14      188
# 17.3    162
# 13.3    157
# 12.5     38
# 11.6     29
# 12        6
# 13.9      6
# 13.5      5
# 12.3      5
# 15.4      4
# 15        4
# 35.6      3
# 10.1      3
# 24        2
# 13        2
# 18.4      1
# 27.3      1
# 33.5      1
# ?         1
# 31.6      1
# 17        1
# 14.1      1
# 11.3      1
# 25.6      1
# Name: count, dtype: int64

# %%
df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', '17.3', '13.5', '12.5', '13',
#        '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '10.1'],
#       dtype=object)

# %%
df[df['Inches'].isnull()].index
# Out:
# Index([], dtype='int64')

# %%
df[df['Inches']=='?'].index.tolist()
# Out:
# [476]

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Inches'].replace('?', np.nan)
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1269    15.6
# 1270      14
# 1271    13.3
# 1272      14
# 1273    15.6
# Name: Inches, Length: 1244, dtype: object

# %%
df[df['Inches']=='?'].index.tolist()
# Out:
# [476]

# %%
df.loc[476]
# Out:
# Company                                    Dell
# TypeName                            Workstation
# Inches                                        ?
# ScreenResolution              Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                         Nvidia Quadro M1200
# OpSys                                Windows 10
# Weight                                   1.78kg
# Price                                 128298.24
# Name: 476, dtype: object

# %%
df['Inches'] = df['Inches'].astype(float)

# %%
df['Inches'] = df['Inches'].replace(['?', 'unknown', ''], np.nan)

# %%
df.loc[476]
# Out:
# Company                                    Dell
# TypeName                            Workstation
# Inches                                      NaN
# ScreenResolution              Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                         Nvidia Quadro M1200
# OpSys                                Windows 10
# Weight                                   1.78kg
# Price                                 128298.24
# Name: 476, dtype: object

# %%
df['Inches'].replace('?', np.nan)
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1269    15.6
# 1270    14.0
# 1271    13.3
# 1272    14.0
# 1273    15.6
# Name: Inches, Length: 1244, dtype: float64

# %%
df.loc[476]
# Out:
# Company                                    Dell
# TypeName                            Workstation
# Inches                                      NaN
# ScreenResolution              Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                         Nvidia Quadro M1200
# OpSys                                Windows 10
# Weight                                   1.78kg
# Price                                 128298.24
# Name: 476, dtype: object

# %%
df.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df['Inches']= df['Inches'].fillna(df['Inches'].mean())

# %%
df.loc[476]
# Out:
# Company                                    Dell
# TypeName                            Workstation
# Inches                                15.138858
# ScreenResolution              Full HD 1920x1080
# Cpu                 Intel Core i7 7700HQ 2.8GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                         Nvidia Quadro M1200
# OpSys                                Windows 10
# Weight                                   1.78kg
# Price                                 128298.24
# Name: 476, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        401
# 1TB HDD                          209
# 500GB HDD                        121
# 512GB SSD                        112
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         72
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                35
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 64GB Flash Storage                12
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          4
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df[df['Memory']=='?'].index.tolist()
# Out:
# [770]

# %%
common_Memory = df['Memory'].value_counts().idxmax()

# %%
df['Memory'] = df['Memory'].replace('?', common_Memory)

# %%
df['Memory'].loc[770]
# Out:
# '256GB SSD'

# %% [markdown]
# # Find mode
# memory_mode = df['Memory'].mode()
# df['Memory'] =  df['Memory'].fillna(memory_mode)[0]

# %% [markdown]
# ## How to sloce Validity Issues

# %%
# this values might be 2kg
df.loc[df['Weight'] == '0.0002kg', 'Weight'] = '2.0kg'

# %%
df.loc[df['Weight'] == '8.4kg', 'Weight'] = '1.27kg'

# %% [markdown]
# ## Accuracy Issues

# %%
## 64GB to 8GB
df.loc[[68, 702], 'Ram'] = '8GB'

# %%
df.loc[df['Ram'] == '1GB', 'Ram'] = '8GB'

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Gaming', '2 in 1 Convertible',
#        'Workstation', 'Netbook'], dtype=object)

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              689
# Gaming                203
# Ultrabook             189
# 2 in 1 Convertible    112
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df[df['TypeName']=='Netbook'].index.tolist()
# Out:
# [376,
#  430,
#  461,
#  500,
#  504,
#  515,
#  584,
#  695,
#  750,
#  804,
#  805,
#  817,
#  828,
#  888,
#  906,
#  935,
#  990,
#  1049,
#  1094,
#  1215,
#  1230,
#  1268]

# %%
df.loc[df['TypeName'] == 'Netbook', 'TypeName'] = 'Notebook'

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df.to_csv(D:\YIU\YIU\LevelFive\BPS")
